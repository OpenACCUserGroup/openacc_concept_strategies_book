# %% [markdown]
# # Build it

# %%
# !pgc++ --c++11 -pg ThermoTables_CPU.C -o out_CPU
# Out:
# /bin/sh: 1: pgc++: not found

# %% [markdown]
# # Run it

# %%
# !./out_CPU 100000 1000

# %% [markdown]
# # Profile it

# %%
# !gprof out_CPU gmon.out
# Out:
# Flat profile:
#
# Each sample counts as 0.01 seconds.
#   %   cumulative   self              self     total
#  time   seconds   seconds    calls  ns/call  ns/call  name
#  50.77      6.61     6.61 200000000    33.05    33.05  bisection(float, float const*, int)
#  46.08     12.61     6.00 100000000    60.00   126.10  LookupTable2D::interpolate(float, float)
#   1.23     12.77     0.16                             _init
#   1.08     12.91     0.14                             main
#   0.77     13.01     0.10                             ___Z9bisectionfPKfiEND
#   0.08     13.02     0.01                             ___ZN13LookupTable2D11interpolateEffEND
#   0.00     13.02     0.00        1     0.00     0.00  LookupTable2D::LookupTable2D()
#   0.00     13.02     0.00        1     0.00     0.00  LookupTable2D::~LookupTable2D()
#   0.00     13.02     0.00        1     0.00     0.00  __sti___18_ThermoTables_CPU_C_e48536f4
#
#  %         the percentage of the total running time of the
# ...
